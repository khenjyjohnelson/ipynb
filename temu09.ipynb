# %% [markdown]
# ##Temu 9

# %% [markdown]
# ### Pandas

# %% [markdown]
# Pengenalan Pandas

# %%
import pandas as pd

# %% [markdown]
# Pandas Object/Data Structures

# %%
import pandas as pd

data = pd.Series([0.25, 0.5, 0.75, 1.0])
data
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64

# %% [markdown]
# Pandas Data Indexing and Selection

# %%
data.values
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64

# %%
data.index

# %%
data[1]
data[:3]

# %%
data = pd.Series([0.25,0.5,0.75,1.0], index=[chr(i) for i in range(97, (97+4))])
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64
