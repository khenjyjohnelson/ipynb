# %% [markdown]
# ##Temu 7

# %% [markdown]
# ### Fungsi

# %% [markdown]
# Fungsi dalam pemrograman python

# %% [markdown]
# Mendefinisikan fungsi

# %% [markdown]
# Memanggil fungsi

# %% [markdown]
# Pernyataan return

# %% [markdown]
# Argumen fungsi

# %% [markdown]
# ### Modul

# %% [markdown]
# ###Operasi File

# %% [markdown]
# Membaca/Membuka file python

# %% [markdown]
# Menulis file di python

# %% [markdown]
# Menutup file di python
