# %%
# This R environment comes with many helpful analytics packages installed
# It is defined by the kaggle/rstats Docker image: https://github.com/kaggle/docker-rstats
# For example, here's a helpful package to load

library(tidyverse) # metapackage of all tidyverse packages

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

list.files(path = "../input")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # SAW

# %% [markdown]
# ##  1a. Contoh

# %%
# Contoh 1

w <- c(5,3,4,4,2)
a1 <- c(4,4,5,3,3)
a2 <- c(3,3,4,2,3)
a3 <- c(5,4,2,2,2)
x <- data.frame(a1,a2,a3)
x <- data.frame(t(x))

n_col <- ncol(x)
n_row <- nrow(x)

r <- data.frame(matrix(nrow=n_row,ncol=n_col))

for (j in 1:n_col){
  r[j] <- x[j]/max(x[j])
}

v <- matrix()

for (i in 1:n_row) {
  v[i] <- sum(r[i,] * w)
}

for (i in 1:n_row){
   if (v[i] == max(v)){
     cat("Alternatif yang dipilih adalah Alternatif", i)
     }
}
# Out:
# Alternatif yang dipilih adalah Alternatif 1

# %%
# Contoh 2

w <- c(5,3,4,4,2)
a1 <- c(4,4,5,3,3)
a2 <- c(3,3,4,2,3)
a3 <- c(5,4,2,2,2)
x <- data.frame(a1,a2,a3)
x <- data.frame(t(x))

x

c <- c('cost', 'benefit', 'cost', 'cost', 'cost')

n_col <- ncol(x)
n_row <- nrow(x)
r <- data.frame(matrix(nrow=n_row,ncol=n_col))

for (j in 1:n_col){
    if (c[j] == 'benefit'){
        r[j] <- x[j]/max(x[j])
    } else if (c[j] == 'cost') {
        r[j] <- min(x[j])/x[j]
    }
}


v <- matrix()

r

for (i in 1:n_row) {
  v[i] <- sum(r[i,] * w)
}

v

for (i in 1:n_row){
   if (v[i] == max(v)){
     cat("Alternatif yang dipilih adalah Alternatif", i)
     }
}
# Out:
#    X1 X2 X3 X4 X5
# a1 4  4  5  3  3
# a2 3  3  4  2  3
# a3 5  4  2  2  2
#   X1   X2   X3  X4        X5
# 1 0.75 1.00 0.4 0.6666667 0.6666667
# 2 1.00 0.75 0.5 1.0000000 0.6666667
# 3 0.60 1.00 1.0 1.0000000 1.0000000
# [1] 12.35000 14.58333 16.00000
# Alternatif yang dipilih adalah Alternatif 3

# %%
# Contoh 3

w <- c(5,3,4,4,2)
a1 <- c(4,4,5,3,3)
a2 <- c(3,3,4,2,3)
a3 <- c(5,4,2,2,2)
x <- data.frame(a1,a2,a3)
x <- data.frame(t(x))

x

c <- c('cost', 'benefit', 'cost', 'cost', 'cost')

n_col <- ncol(x)
n_row <- nrow(x)
r <- data.frame(matrix(nrow=n_row,ncol=n_col))

for (j in 1:n_col){
    if (c[j] == 'benefit'){
        r[j] <- x[j]/max(x[j])
    } else if (c[j] == 'cost') {
        r[j] <- min(x[j])/x[j]
    }
}


v <- matrix()

r

for (i in 1:n_row) {
  v[i] <- sum(r[i,] * w)
}

v

for (i in 1:n_row){
   if (v[i] == max(v)){
     cat("Alternatif yang dipilih adalah Alternatif", i)
     }
}
# Out:
#    X1 X2 X3 X4 X5
# a1 4  4  5  3  3
# a2 3  3  4  2  3
# a3 5  4  2  2  2
#   X1   X2   X3  X4        X5
# 1 0.75 1.00 0.4 0.6666667 0.6666667
# 2 1.00 0.75 0.5 1.0000000 0.6666667
# 3 0.60 1.00 1.0 1.0000000 1.0000000
# [1] 12.35000 14.58333 16.00000
# Alternatif yang dipilih adalah Alternatif 3

# %% [markdown]
# ##  1b. Latihan

# %%
# Latihan 1

w <- c(25,10,35,10,20)
a1 <- c(5,4,3,4,3)
a2 <- c(3,5,5,4,5)
a3 <- c(2,2,1,3,1)
x <- data.frame(a1,a2,a3)
x <- data.frame(t(x))

c <- c('benefit', 'benefit', 'cost', 'benefit', 'benefit')

n_col <- ncol(x)
n_row <- nrow(x)
r <- data.frame(matrix(nrow=n_row,ncol=n_col))

for (j in 1:n_col){
    if (c[j] == 'benefit'){
        r[j] <- x[j]/max(x[j])
    } else if (c[j] == 'cost') {
        r[j] <- min(x[j])/x[j]
    }
}


v <- matrix()

for (i in 1:n_row) {
  v[i] <- sum(r[i,] * w)
}

for (i in 1:n_row){
   if (v[i] == max(v)){
     cat("Alternatif yang dipilih adalah Alternatif", i)
     }
}
# Out:
# Alternatif yang dipilih adalah Alternatif 1

# %%
# Latihan 2

w <- c(30,35,35)
a1 <- c(5,3,5)
a2 <- c(3,1,5)
a3 <- c(5,3,5)
a4 <- c(3,3,5)
a5 <- c(5,3,5)
x <- data.frame(a1,a2,a3,a4,a5)
x <- data.frame(t(x))

c <- c('cost', 'benefit', 'benefit')

n_col <- ncol(x)
n_row <- nrow(x)
r <- data.frame(matrix(nrow=n_row,ncol=n_col))

for (j in 1:n_col){
    if (c[j] == 'benefit'){
        r[j] <- x[j]/max(x[j])
    } else if (c[j] == 'cost') {
        r[j] <- min(x[j])/x[j]
    }
}


v <- matrix()

for (i in 1:n_row) {
  v[i] <- sum(r[i,] * w)
}

for (i in 1:n_row){
   if (v[i] == max(v)){
     cat("Alternatif yang dipilih adalah Alternatif", i)
     }
}
# Out:
# Alternatif yang dipilih adalah Alternatif 4

# %%
# Latihan 3

w <- c(20,20,30,30)
a1 <- c(2,1,4,5)
a2 <- c(1,4,2,3)
a3 <- c(3,2,3,3)
a4 <- c(2,4,5,3)
a5 <- c(3,2,2,3)
a6 <- c(4,1,1,1)
a7 <- c(5,3,5,4)
x <- data.frame(a1,a2,a3,a4,a5,a6,a7)
x <- data.frame(t(x))

c <- c('benefit', 'benefit', 'benefit', 'cost')

n_col <- ncol(x)
n_row <- nrow(x)
r <- data.frame(matrix(nrow=n_row,ncol=n_col))

for (j in 1:n_col){
    if (c[j] == 'benefit'){
        r[j] <- x[j]/max(x[j])
    } else if (c[j] == 'cost') {
        r[j] <- min(x[j])/x[j]
    }
}


v <- matrix()

for (i in 1:n_row) {
  v[i] <- sum(r[i,] * w)
}

for (i in 1:n_row){
   if (v[i] == max(v)){
     cat("Alternatif yang dipilih adalah Alternatif", i)
     }
}
# Out:
# Alternatif yang dipilih adalah Alternatif 7

# %% [markdown]
# ##  1c. Versi Bisa Input

# %%
# Versi bisa input

# Allow user input for the number of criteria and alternatives
repeat {
  num_criteria <- suppressWarnings(as.integer(readline("Enter the number of criteria: ")))
  if (!is.na(num_criteria) && num_criteria > 0) break
  cat("Invalid input. Please enter a positive integer.\n")
}

repeat {
  num_alternatives <- suppressWarnings(as.integer(readline("Enter the number of alternatives: ")))
  if (!is.na(num_alternatives) && num_alternatives > 0) break
  cat("Invalid input. Please enter a positive integer.\n")
}

# Initialize empty lists for weights and criteria type
w <- numeric(num_criteria)
c <- character(num_criteria)

# Get weights from user
cat("Enter weights for each criterion: \n")
for (i in 1:num_criteria) {
  repeat {
    w[i] <- suppressWarnings(as.numeric(readline(paste("Weight for criterion", i, ": "))))
    if (!is.na(w[i]) && w[i] > 0) break
    cat("Invalid input. Please enter a positive number.\n")
  }
}

# Get benefit/cost type from user
cat("Enter 'benefit' or 'cost' for each criterion: \n")
for (i in 1:num_criteria) {
  repeat {
    c[i] <- tolower(readline(paste("Type for criterion", i, "(benefit/cost): ")))
    if (c[i] %in% c("benefit", "cost")) break
    cat("Invalid input. Please enter 'benefit' or 'cost'.\n")
  }
}

# Create an empty dataframe to store alternatives
data_list <- list()

# Get alternative values from user
for (i in 1:num_alternatives) {
  alt_values <- numeric(num_criteria)
  for (j in 1:num_criteria) {
    repeat {
      alt_values[j] <- suppressWarnings(as.numeric(readline(paste("Enter value for Alternative", i, "Criterion", j, ": "))))
      if (!is.na(alt_values[j])) break
      cat("Invalid input. Please enter a numeric value.\n")
    }
  }
  data_list[[paste0("a", i)]] <- alt_values
}

# Convert to dataframe
x <- data.frame(data_list)
x <- data.frame(t(x))

# Normalize the decision matrix
n_col <- ncol(x)
n_row <- nrow(x)
r <- data.frame(matrix(nrow=n_row, ncol=n_col))

for (j in 1:n_col) {
  if (c[j] == 'benefit') {
    r[j] <- x[j] / max(x[j])
  } else if (c[j] == 'cost') {
    r[j] <- min(x[j]) / x[j]
  }
}

# Calculate the final score
v <- numeric(n_row)
for (i in 1:n_row) {
  v[i] <- sum(r[i, ] * w)
}

# Determine the best alternative
for (i in 1:n_row) {
  if (v[i] == max(v)) {
    cat("Alternatif yang dipilih adalah Alternatif", i, "\n")
  }
}
# Out:
# Enter the number of criteria:  4
# Enter the number of alternatives:  7
# Enter weights for each criterion:
# Weight for criterion 1 :  20
# Weight for criterion 2 :  20
# Weight for criterion 3 :  30
# Weight for criterion 4 :  30
# Enter 'benefit' or 'cost' for each criterion:
# Type for criterion 1 (benefit/cost):  benefit
# Type for criterion 2 (benefit/cost):  benefit
# Type for criterion 3 (benefit/cost):  benefit
# Type for criterion 4 (benefit/cost):  cost
# Enter value for Alternative 1 Criterion 1 :  2
# Enter value for Alternative 1 Criterion 2 :  1
# Enter value for Alternative 1 Criterion 3 :  4
# Enter value for Alternative 1 Criterion 4 :  5
# Enter value for Alternative 2 Criterion 1 :  1
# Enter value for Alternative 2 Criterion 2 :  4
# Enter value for Alternative 2 Criterion 3 :  2
# Enter value for Alternative 2 Criterion 4 :  3
# Enter value for Alternative 3 Criterion 1 :  3
# Enter value for Alternative 3 Criterion 2 :  2
# ...

# %% [markdown]
# ## 1d. UAS

# %%
# Teknik Contoh 1: Tanpa Benefit

w <- c(5, 4, 3, 3, 3)
a1 <- c(3000000, 6.4, 110, 4, 64)
a2 <- c(2500000, 6.3, 140, 4, 64)
a3 <- c(2000000, 6.52, 170, 4, 64)
a4 <- c(2000000, 6.5, 170, 4, 64)
a5 <- c(2800000, 6.53, 185, 4, 64)


x <- data.frame(a1,a2,a3,a4,a5)
x <- data.frame(t(x))

n_col <- ncol(x)
n_row <- nrow(x)
r <- data.frame(matrix(nrow=n_row,ncol=n_col))

for (j in 1:n_col){
  r[j] <- x[j]/max(x[j])
}

v <- matrix()

for (i in 1:n_row) {
  v[i] <- sum(r[i,] * w)
}

for (i in 1:n_row){
   if (v[i] == max(v)){
     cat("Alternatif yang dipilih adalah Alternatif", i)
     }
}
# Out:
# Alternatif yang dipilih adalah Alternatif 5

# %%
# Teknik Contoh 2: Dengan Cost Benefit

w <- c(5, 4, 3, 3, 3)
a1 <- c(3000000, 6.4, 110, 4, 64)
a2 <- c(2500000, 6.3, 140, 4, 64)
a3 <- c(2000000, 6.52, 170, 4, 64)
a4 <- c(2000000, 6.5, 170, 4, 64)
a5 <- c(2800000, 6.53, 185, 4, 64)
c <- c('cost', 'benefit', 'benefit', 'benefit', 'benefit')

x <- data.frame(a1,a2,a3,a4,a5)
x <- data.frame(t(x))

n_col <- ncol(x)
n_row <- nrow(x)
r <- data.frame(matrix(nrow=n_row,ncol=n_col))

for (j in 1:n_col){
    if (c[j] == 'benefit'){
        r[j] <- x[j]/max(x[j])
    } else if (c[j] == 'cost') {
        r[j] <- min(x[j])/x[j]
    }
}

v <- matrix()

for (i in 1:n_row) {
  v[i] <- sum(r[i,] * w)
}

for (i in 1:n_row){
   if (v[i] == max(v)){
     cat("Alternatif yang dipilih adalah Alternatif", i)
     }
}
# Out:
# Alternatif yang dipilih adalah Alternatif 3

# %% [markdown]
# # Weighted Product

# %% [markdown]
# ## 2a. Contoh

# %%
# Contoh 1

w <- c(5,3,4,4,2)
a1 <- c(4,4,5,3,3)
a2 <- c(3,3,4,2,3)
a3 <- c(5,4,2,2,2)
x <- data.frame(a1,a2,a3)
x <- data.frame(t(x))

c <- c('cost', 'benefit', 'cost', 'cost', 'cost')

# Normalisasi Bobot
n_col <- ncol(x)
new_w <- c()

for (j in 1:n_col) {
    new_w[j] <- w[j]/sum(w)
}

# Menemukan nilai preferensi alternatif
n_row <- nrow(x)
s_temp <- data.frame(matrix(nrow=n_row,ncol=n_col))
s <- c()

for (i in 1:n_row) {
    for (j in 1:n_col){
        if (c[j] == 'benefit'){
            s_temp[i,j] <- x[i,j]^new_w[j]
        } 
        else if (c[j] == 'cost') {
            s_temp[i,j] <- x[i,j]^(-new_w[j])
        }
    }
}

s_temp


for (i in 1:n_row) {
  s[i] <- sum(s_temp[i,])
}

s


# 6. Perankingan terhadap alternatif
v <- c()

for (i in 1:n_row) {
    v[i] <- s[i]/sum(s)
}
for (i in 1:n_row) {
    if (v[i]==max(v)) {
        cat("Alternatif yang dipilih adalah Alternatif", i)
    }
}

v
# Out:
#   X1        X2       X3        X4       X5
# 1 0.6803950 1.259921 0.6993158 0.783381 0.8850882
# 2 0.7369980 1.200937 0.7348672 0.857244 0.8850882
# 3 0.6395016 1.259921 0.8572440 0.857244 0.9258747
# [1] 4.308101 4.415134 4.539785
# Alternatif yang dipilih adalah Alternatif 3
# [1] 0.3248205 0.3328906 0.3422889

# %%
# Contoh 2

w <- c(5,3,4,4,2)
a1 <- c(0.75,2000,18,50,500)
a2 <- c(0.5,1500,20,40, 450)
a3 <- c(0.9,2050,35,35,800)

x <- data.frame(a1,a2,a3)
x <- data.frame(t(x))

c <- c('cost', 'benefit', 'cost', 'benefit', 'cost')

n_col <- ncol(x)
new_w <- c()

for (j in 1:n_col) {
    new_w[j] <- w[j]/sum(w)
}
n_row <- nrow(x)
s_temp <- data.frame(matrix(nrow=n_row,ncol=n_col))
s <- c()

for (i in 1:n_row) {
    for (j in 1:n_col){
        if (c[j] == 'benefit'){
            s_temp[i,j] <- x[i,j]^new_w[j]
        } 
        else if (c[j] == 'cost') {
            s_temp[i,j] <- x[i,j]^(-new_w[j])
        }
    }
}

s_temp


for (i in 1:n_row) {
  s[i] <- sum(s_temp[i,])
}

s



v <- c()

for (i in 1:n_row) {
    v[i] <- s[i]/sum(s)
}
for (i in 1:n_row) {
    if (v[i]==max(v)) {
        cat("Alternatif yang dipilih adalah Alternatif", i)
    }
}

v
# Out:
#   X1       X2       X3        X4       X5
# 1 1.083191 3.549537 0.5260785 2.385332 0.5013193
# 2 1.212326 3.383363 0.5139043 2.269935 0.5072226
# 3 1.029699 3.564175 0.4538097 2.203567 0.4758110
# [1] 8.045458 7.886750 7.727061
# Alternatif yang dipilih adalah Alternatif 1
# [1] 0.3400552 0.3333471 0.3265976

# %% [markdown]
# ## 2b. Latihan

# %%
# Latihan 1

w <- c(25,10,35,10,20)
a1 <- c(5,4,3,4,3)
a2 <- c(3,5,5,4,5)
a3 <- c(2,2,1,3,1)
x <- data.frame(a1,a2,a3)
x <- data.frame(t(x))

c <- c('benefit', 'benefit', 'cost', 'benefit', 'benefit')

n_col <- ncol(x)
new_w <- c()

for (j in 1:n_col) {
    new_w[j] <- w[j]/sum(w)
}
n_row <- nrow(x)
s_temp <- data.frame(matrix(nrow=n_row,ncol=n_col))
s <- c()

for (i in 1:n_row) {
    for (j in 1:n_col){
        if (c[j] == 'benefit'){
            s_temp[i,j] <- x[i,j]^new_w[j]
        } 
        else if (c[j] == 'cost') {
            s_temp[i,j] <- x[i,j]^(-new_w[j])
        }
    }
}

s_temp


for (i in 1:n_row) {
  s[i] <- sum(s_temp[i,])
}

s



v <- c()

for (i in 1:n_row) {
    v[i] <- s[i]/sum(s)
}
for (i in 1:n_row) {
    if (v[i]==max(v)) {
        cat("Alternatif yang dipilih adalah Alternatif", i)
    }
}

v
# Out:
#   X1       X2       X3        X4       X5
# 1 1.495349 1.148698 0.6807812 1.148698 1.245731
# 2 1.316074 1.174619 0.5693253 1.148698 1.379730
# 3 1.189207 1.071773 1.0000000 1.116123 1.000000
# [1] 5.719258 5.588446 5.377104
# Alternatif yang dipilih adalah Alternatif 1
# [1] 0.3427824 0.3349422 0.3222754

# %%
# Latihan 2

w <- c(30,35,35)
a1 <- c(5,3,5)
a2 <- c(3,1,5)
a3 <- c(5,3,5)
a4 <- c(3,3,5)
a5 <- c(5,3,5)
x <- data.frame(a1,a2,a3,a4,a5)
x <- data.frame(t(x))

c <- c('cost', 'benefit', 'benefit')

n_col <- ncol(x)
new_w <- c()

for (j in 1:n_col) {
    new_w[j] <- w[j]/sum(w)
}
n_row <- nrow(x)
s_temp <- data.frame(matrix(nrow=n_row,ncol=n_col))
s <- c()

for (i in 1:n_row) {
    for (j in 1:n_col){
        if (c[j] == 'benefit'){
            s_temp[i,j] <- x[i,j]^new_w[j]
        } 
        else if (c[j] == 'cost') {
            s_temp[i,j] <- x[i,j]^(-new_w[j])
        }
    }
}

s_temp


for (i in 1:n_row) {
  s[i] <- sum(s_temp[i,])
}

s



v <- c()

for (i in 1:n_row) {
    v[i] <- s[i]/sum(s)
}
for (i in 1:n_row) {
    if (v[i]==max(v)) {
        cat("Alternatif yang dipilih adalah Alternatif", i)
    }
}

v
# Out:
#   X1        X2       X3
# 1 0.6170339 1.468901 1.756465
# 2 0.7192231 1.000000 1.756465
# 3 0.6170339 1.468901 1.756465
# 4 0.7192231 1.468901 1.756465
# 5 0.6170339 1.468901 1.756465
# [1] 3.842400 3.475688 3.842400 3.944589 3.842400
# Alternatif yang dipilih adalah Alternatif 4
# [1] 0.2027922 0.1834381 0.2027922 0.2081855 0.2027922

# %%
# Latihan 3

w <- c(20,20,30,30)
a1 <- c(2,1,4,5)
a2 <- c(1,4,2,3)
a3 <- c(3,2,3,3)
a4 <- c(2,4,5,3)
a5 <- c(3,2,2,3)
a6 <- c(4,1,1,1)
a7 <- c(5,3,5,4)
x <- data.frame(a1,a2,a3,a4,a5,a6,a7)
x <- data.frame(t(x))

c <- c('benefit', 'benefit', 'benefit', 'cost')

n_col <- ncol(x)
new_w <- c()

for (j in 1:n_col) {
    new_w[j] <- w[j]/sum(w)
}
n_row <- nrow(x)
s_temp <- data.frame(matrix(nrow=n_row,ncol=n_col))
s <- c()

for (i in 1:n_row) {
    for (j in 1:n_col){
        if (c[j] == 'benefit'){
            s_temp[i,j] <- x[i,j]^new_w[j]
        } 
        else if (c[j] == 'cost') {
            s_temp[i,j] <- x[i,j]^(-new_w[j])
        }
    }
}

s_temp


for (i in 1:n_row) {
  s[i] <- sum(s_temp[i,])
}

s



v <- c()

for (i in 1:n_row) {
    v[i] <- s[i]/sum(s)
}
for (i in 1:n_row) {
    if (v[i]==max(v)) {
        cat("Alternatif yang dipilih adalah Alternatif", i)
    }
}

v
# Out:
#   X1       X2       X3       X4
# 1 1.148698 1.000000 1.515717 0.6170339
# 2 1.000000 1.319508 1.231144 0.7192231
# 3 1.245731 1.148698 1.390389 0.7192231
# 4 1.148698 1.319508 1.620657 0.7192231
# 5 1.245731 1.148698 1.231144 0.7192231
# 6 1.319508 1.000000 1.000000 1.0000000
# 7 1.379730 1.245731 1.620657 0.6597540
# [1] 4.281449 4.269875 4.504042 4.808086 4.344797 4.319508 4.905871
# Alternatif yang dipilih adalah Alternatif 7
# [1] 0.1362060 0.1358378 0.1432874 0.1529599 0.1382213 0.1374168 0.1560708
